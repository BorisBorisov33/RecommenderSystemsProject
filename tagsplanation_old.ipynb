# %% [markdown]
# # Tagsplanation
# ## Loading stuff

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
file_name_filtered = "filtered_df"
file_name_recipes = "RAW_recipes"
csv_extension = ".csv"
directory = "datasets/"

# %%
id = 'id'
tags = 'tags'
tags_norm = 'tags_normalized'
tags_vec = 'tags_vectorized'
FILTERED_COLUMNS = ["user_id", "recipe_id", "date", "rating", "review"]
RECIPE_COLUMNS = [id, tags]

# %%
df_filtered = pd.read_csv(directory + file_name_filtered + csv_extension)
df_recipe = pd.read_csv(directory + file_name_recipes + csv_extension)
df_filtered = df_filtered[FILTERED_COLUMNS]
df_recipe = df_recipe[RECIPE_COLUMNS]
df_filtered.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    57222      85009  2011-10-01       5
# 1   124416     120345  2011-08-06       0
# 2    76535     134728  2005-09-02       4
# 3   255338     134728  2008-04-11       5
# 4   136726     197160  2006-11-25       5
#
#                                               review
# 0  Made the cheddar bacon topping, adding a sprin...
# 1  Just an observation, so I will not rate.  I fo...
# 2                                         Very good!
# 3  First time using liquid smoke in a recipe. Mad...
# 4  I used this mix to make meat balls.Very simple...

# %%
df_recipe.head()
# Out:
#        id                                               tags
# 0  137739  ['60-minutes-or-less', 'time-to-make', 'course...
# 1   31490  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  112140  ['time-to-make', 'course', 'preparation', 'mai...
# 3   59389  ['60-minutes-or-less', 'time-to-make', 'course...
# 4   44061  ['weeknight', 'time-to-make', 'course', 'main-...

# %% [markdown]
# ## Fixing tags data type and structure

# %%
forbidden_characters = [',', '[', ']', ' ', '', '\'']
all_tags = []
df_recipe[tags_norm] = ''
for id, value in df_recipe.iterrows():
    curr_tag = value[tags]
    curr_word = str()
    for curr_char in curr_tag:
        if curr_char not in forbidden_characters:
            curr_word+=curr_char
        else:
            if curr_word != '':
                all_tags.append(curr_word.lower())
                # this method might create an error if you have a different
                # version of pandas than me:
                df_recipe.set_value(id, tags_norm, all_tags)
                curr_word = str()
    all_tags = []
# Out:
# C:\Users\vanku\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app

# %%
df_recipe.head()
# Out:
#        id                                               tags  \
# 0  137739  ['60-minutes-or-less', 'time-to-make', 'course...
# 1   31490  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  112140  ['time-to-make', 'course', 'preparation', 'mai...
# 3   59389  ['60-minutes-or-less', 'time-to-make', 'course...
# 4   44061  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                      tags_normalized
# 0  [60-minutes-or-less, time-to-make, course, mai...
# 1  [30-minutes-or-less, time-to-make, course, mai...
# 2  [time-to-make, course, preparation, main-dish,...
# 3  [60-minutes-or-less, time-to-make, course, mai...
# 4  [weeknight, time-to-make, course, main-ingredi...

# %% [markdown]
# ## Word2vec

# %%
model1 = gensim.models.Word2Vec(df_recipe.tags_normalized, min_count = 1)

# %%
model1.wv.most_similar('weeknight')
# Out:
# [('60-minutes-or-less', 0.8781963586807251),
#  ('30-minutes-or-less', 0.7874325513839722),
#  ('time-to-make', 0.7398199439048767),
#  ('lactose', 0.7229251861572266),
#  ('course', 0.6985160708427429),
#  ('main-ingredient', 0.6447389125823975),
#  ('15-minutes-or-less', 0.6116815805435181),
#  ('cuisine', 0.604736328125),
#  ('preparation', 0.515422523021698),
#  ('south-west-pacific', 0.5001165866851807)]

# %%
model1.wv.similarity('weeknight', 'celebrity')
# Out:
# 0.4921438

# %%
all_vec = []
df_recipe[tags_vec] = ''
for id, value in df_recipe.iterrows():
    for tag in value[tags_norm]:
        all_vec.append(model1.wv[tag])
    df_recipe.set_value(id, tags_vec, all_vec)# might generate error, see above
    all_vec = []
# Out:
# C:\Users\vanku\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %% [markdown]
# ## Train ML model

# %%
df_filtered.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    57222      85009  2011-10-01       5
# 1   124416     120345  2011-08-06       0
# 2    76535     134728  2005-09-02       4
# 3   255338     134728  2008-04-11       5
# 4   136726     197160  2006-11-25       5
#
#                                               review
# 0  Made the cheddar bacon topping, adding a sprin...
# 1  Just an observation, so I will not rate.  I fo...
# 2                                         Very good!
# 3  First time using liquid smoke in a recipe. Mad...
# 4  I used this mix to make meat balls.Very simple...

# %%
df_recipe.rename({id:'recipe_id'}, axis=1, inplace=True)

# %%
print(len(df_recipe))
df_recipe = df_recipe[df_recipe['id'].isin(df_filtered['recipe_id'].to_list())]
print(len(df_recipe))
df_recipe.reset_index(inplace=True, drop=True)
df_recipe.head()
# Out:
# 231637
# 103662
#       id                                               tags  \
# 0  31490  ['30-minutes-or-less', 'time-to-make', 'course...
# 1  67888  ['weeknight', 'time-to-make', 'course', 'main-...
# 2  70971  ['weeknight', 'time-to-make', 'course', 'main-...
# 3  75452  ['weeknight', 'time-to-make', 'course', 'main-...
# 4  67547  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                      tags_normalized  \
# 0  [30-minutes-or-less, time-to-make, course, mai...
# 1  [weeknight, time-to-make, course, main-ingredi...
# 2  [weeknight, time-to-make, course, main-ingredi...
# 3  [weeknight, time-to-make, course, main-ingredi...
# 4  [weeknight, time-to-make, course, main-ingredi...
#
#                                      tags_vectorized
# 0  [[-0.008353826, -2.0104654, -1.60594, 2.132089...
# 1  [[1.7261446, -2.657304, -2.0291271, 0.72138834...
# 2  [[1.7261446, -2.657304, -2.0291271, 0.72138834...
# 3  [[1.7261446, -2.657304, -2.0291271, 0.72138834...
# 4  [[1.7261446, -2.657304, -2.0291271, 0.72138834...

# %%
df_full = pd.merge(df_filtered, df_recipe, left_on='recipe_id', right_on='id', how='left')

# %%
del df_full['tags']
#del df_full['tags_normalized']
del df_full['review']
del df_full['date']

# %%
df_full.head()
# Out:
#    user_id  recipe_id  rating      id  \
# 0    57222      85009       5   85009
# 1   124416     120345       0  120345
# 2    76535     134728       4  134728
# 3   255338     134728       5  134728
# 4   136726     197160       5  197160
#
#                                      tags_normalized  \
# 0  [15-minutes-or-less, time-to-make, course, mai...
# 1  [15-minutes-or-less, time-to-make, course, mai...
# 2  [60-minutes-or-less, time-to-make, main-ingred...
# 3  [60-minutes-or-less, time-to-make, main-ingred...
# 4  [30-minutes-or-less, time-to-make, course, mai...
#
#                                      tags_vectorized
# 0  [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
# 1  [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
# 2  [[1.0269203, -1.972872, -2.1189754, 2.0314367,...
# 3  [[1.0269203, -1.972872, -2.1189754, 2.0314367,...
# 4  [[-0.008353826, -2.0104654, -1.60594, 2.132089...

# %%
def document_vector(doc):
    """Create document vectors by averaging word vectors. Remove out-of-vocabulary words."""
    doc = [word for word in doc if word in list(model1.wv.index_to_key)]
    #doc = [word for level in doc for word in level if word in list(model1.wv.index_to_key)]
    #print('doc', doc)
    return np.mean(model1.wv[doc], axis=0)

# %%
doc_1 = df_recipe['tags_normalized'][0]

# %%
df_full['doc_vec'] = ''
for index, value in df_full.iterrows():
    if value['tags_normalized'] != '':
        curr_arr = np.asarray(document_vector(value['tags_normalized']))
        if len(curr_arr) == 100:
            df_full.set_value(index, 'doc_vec', curr_arr)
    else:
        df_full.set_value(index, 'doc_vec', np.asarray(np.zeros(100)))
df_full.head()
# Out:
# C:\Users\vanku\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\vanku\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#    user_id  recipe_id  rating      id  \
# 0    57222      85009       5   85009
# 1   124416     120345       0  120345
# 2    76535     134728       4  134728
# 3   255338     134728       5  134728
# 4   136726     197160       5  197160
#
#                                      tags_normalized  \
# 0  [15-minutes-or-less, time-to-make, course, mai...
# 1  [15-minutes-or-less, time-to-make, course, mai...
# 2  [60-minutes-or-less, time-to-make, main-ingred...
# 3  [60-minutes-or-less, time-to-make, main-ingred...
# 4  [30-minutes-or-less, time-to-make, course, mai...
#
#                                      tags_vectorized  \
# 0  [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
# 1  [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
# 2  [[1.0269203, -1.972872, -2.1189754, 2.0314367,...
# 3  [[1.0269203, -1.972872, -2.1189754, 2.0314367,...
# 4  [[-0.008353826, -2.0104654, -1.60594, 2.132089...
#
#                                              doc_vec
# 0  [-0.1545624, -0.92504364, 0.27831176, 0.014024...
# 1  [-0.464551, -0.9952115, 0.29176545, -0.0407484...
# 2  [-0.94547033, -0.6833449, -0.2319088, -0.12324...
# 3  [-0.94547033, -0.6833449, -0.2319088, -0.12324...
# 4  [-0.43313128, -1.2558981, -0.39539507, 0.08085...

# %%
test_array = df_full['doc_vec'].to_list()
Xnew = np.array(test_array).reshape((1,-1))
Xnew = np.zeros(len(df_full))
rg = XGBRegressor()
y = df_full['rating'].to_list()
Ynew = np.array(y).reshape((1,-1))
mdl = rg.fit(Xnew, Ynew)
# Out:
# C:\Users\vanku\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-a5c1dbd8aed8> in <module>
#       5 y = df_full['rating'].to_list()
#       6 Ynew = np.array(y).reshape((1,-1))
# ----> 7 mdl = rg.fit(Xnew, Ynew)
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     774             eval_qid=None,
#     775             create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
# --> 776             enable_categorical=self.enable_categorical,
#     777         )
#     778         params = self.get_xgb_params()
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\sklearn.py in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, label_transform)
#     293         feature_weights=feature_weights,
#     294         missing=missing,
# --> 295         enable_categorical=enable_categorical,
#     296     )
#     297
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\sklearn.py in <lambda>(**kwargs)
#     773             eval_group=None,
#     774             eval_qid=None,
# --> 775             create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     776             enable_categorical=self.enable_categorical,
#     777         )
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     620             feature_names=feature_names,
#     621             feature_types=feature_types,
# --> 622             enable_categorical=enable_categorical,
#     623         )
#     624         assert handle is not None
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     686     '''Dispatch data for DMatrix.'''
#     687     if not _is_cudf_ser(data) and not _is_pandas_series(data):
# --> 688         _check_data_shape(data)
#     689     if _is_scipy_csr(data):
#     690         return _from_scipy_csr(data, missing, threads, feature_names, feature_types)
#
# C:\Users\vanku\Anaconda3\lib\site-packages\xgboost\data.py in _check_data_shape(data)
#      37 def _check_data_shape(data: Any) -> None:
#      38     if hasattr(data, "shape") and len(data.shape) != 2:
# ---> 39         raise ValueError("Please reshape the input data into 2-dimensional matrix.")
#      40
#      41
#
# ValueError: Please reshape the input data into 2-dimensional matrix.

# %%
df_full_ = df_full.drop(labels=10412, axis=0)
np.vstack(df_full_['doc_vec'])
# Out:
# array([[-0.1545624 , -0.92504364,  0.27831176, ..., -0.08729316,
#          0.48941162, -0.05660954],
#        [-0.464551  , -0.99521148,  0.29176545, ...,  0.4024446 ,
#         -0.09688257,  0.46474418],
#        [-0.94547033, -0.6833449 , -0.2319088 , ...,  0.36478165,
#         -0.68412608,  0.11156012],
#        ...,
#        [ 0.66840112, -0.6241017 , -0.10890383, ..., -0.54412818,
#          0.60159576, -0.1591617 ],
#        [-0.37391147, -0.85031307,  0.00650825, ...,  0.71367639,
#         -0.02232931,  0.44661844],
#        [-0.37391147, -0.85031307,  0.00650825, ...,  0.71367639,
#         -0.02232931,  0.44661844]])

# %%
train, test = train_test_split(df_full_, test_size=0.2)
rg.fit(np.vstack(train['doc_vec']),train.rating)
predicted = rg.predict(np.vstack(test['doc_vec']))
print(predicted)
# Out:
# [4.530293  4.6345816 4.5018263 ... 4.648133  4.5150285 4.43743  ]

# %%
df_full_
# Out:
#         user_id  recipe_id  rating      id  \
# 0         57222      85009       5   85009
# 1        124416     120345       0  120345
# 2         76535     134728       4  134728
# 3        255338     134728       5  134728
# 4        136726     197160       5  197160
# ...         ...        ...     ...     ...
# 237995   594923     249924       5  249924
# 237996  1269180     257796       4  257796
# 237997   126435     166739       5  166739
# 237998   199020      82303       5   82303
# 237999  1122988      82303       5   82303
#
#                                           tags_normalized  \
# 0       [15-minutes-or-less, time-to-make, course, mai...
# 1       [15-minutes-or-less, time-to-make, course, mai...
# 2       [60-minutes-or-less, time-to-make, main-ingred...
# 3       [60-minutes-or-less, time-to-make, main-ingred...
# 4       [30-minutes-or-less, time-to-make, course, mai...
# ...                                                   ...
# 237995  [time-to-make, course, main-ingredient, cuisin...
# 237996  [main-ingredient, preparation, occasion, poult...
# 237997  [30-minutes-or-less, time-to-make, course, pre...
# 237998  [15-minutes-or-less, time-to-make, course, pre...
# 237999  [15-minutes-or-less, time-to-make, course, pre...
#
#                                           tags_vectorized  \
# 0       [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
# 1       [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
# 2       [[1.0269203, -1.972872, -2.1189754, 2.0314367,...
# 3       [[1.0269203, -1.972872, -2.1189754, 2.0314367,...
# 4       [[-0.008353826, -2.0104654, -1.60594, 2.132089...
# ...                                                   ...
# 237995  [[0.50824, -2.4250808, -1.4971544, 2.0699348, ...
# 237996  [[0.37609527, -2.531526, 0.5628416, -0.4621942...
# 237997  [[-0.008353826, -2.0104654, -1.60594, 2.132089...
# 237998  [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
# 237999  [[-0.18661752, -2.6211035, 0.21846467, 2.33371...
#
#                                                   doc_vec
# 0       [-0.1545624, -0.92504364, 0.27831176, 0.014024...
# 1       [-0.464551, -0.9952115, 0.29176545, -0.0407484...
# 2       [-0.94547033, -0.6833449, -0.2319088, -0.12324...
# 3       [-0.94547033, -0.6833449, -0.2319088, -0.12324...
# 4       [-0.43313128, -1.2558981, -0.39539507, 0.08085...
# ...                                                   ...
# 237995  [-0.27955064, -0.9678705, -0.084901325, -0.056...
# 237996  [0.013922434, -0.658329, 0.20771731, -0.253216...
# 237997  [0.6684011, -0.6241017, -0.108903825, -0.86413...
# 237998  [-0.37391147, -0.85031307, 0.006508245, 0.0760...
# 237999  [-0.37391147, -0.85031307, 0.006508245, 0.0760...
#
# [237999 rows x 7 columns]
